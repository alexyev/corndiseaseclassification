# %%
# download and link kaggle to colab
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()

# %%
# you may have to rerun this cell 
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
 # !kaggle datasets list
# Out:
# ref                                                             title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# meirnizri/covid19-dataset                                       COVID-19 Dataset                                 5MB  2022-11-13 15:47:17          13687        387  1.0
# thedevastator/analyzing-credit-card-spending-habits-in-india    Credit Card Spending Habits in India           319KB  2022-12-14 07:30:37            967         41  1.0
# michals22/coffee-dataset                                        Coffee dataset                                  24KB  2022-12-15 20:02:12           3100         75  1.0
# thedevastator/unlock-profits-with-e-commerce-sales-data         E-Commerce Sales Dataset                         6MB  2022-12-03 09:27:17           2381         59  1.0
# thedevastator/jobs-dataset-from-glassdoor                       Salary Prediction                                3MB  2022-11-16 13:52:31           7885        174  1.0
# die9origephit/fifa-world-cup-2022-complete-dataset              Fifa World Cup 2022: Complete Dataset            7KB  2022-12-18 22:51:11           2611        100  1.0
# mattop/highest-grossing-mobile-games                            Highest Grossing Mobile Games                    3KB  2022-12-19 15:20:22            618         28  1.0
# thedevastator/uncover-global-trends-in-mental-health-disorder   Global Trends in Mental Health Disorder          1MB  2022-12-14 05:30:38            851         27  1.0
# rajkumarpandey02/fifa-world-cup-attendance-19302022             FIFA World Cup Attendance 1930-2022              5KB  2022-12-19 10:04:26            811         22  1.0
# thedevastator/revealing-insights-from-youtube-video-and-channe  YouTube Videos and Channels Metadata            82MB  2022-12-14 02:48:24            546         30  0.9411765
# thedevastator/uncovering-insights-to-college-majors-and-their   College Majors and their Graduates              39KB  2022-12-06 16:06:52           1236         35  1.0
# mvieira101/global-cost-of-living                                Global Cost of Living                            1MB  2022-12-03 16:37:53           3686         75  0.9705882
# anashamoutni/students-employability-dataset                     Students' Employability Dataset - Philippines   97KB  2022-12-18 15:51:39            723         29  0.88235295
# swaptr/fifa-world-cup-2022-statistics                           FIFA World Cup 2022 Team Data                   15KB  2022-12-19 00:29:15           2781         61  0.9705882
# thedevastator/the-ultimate-netflix-tv-shows-and-movies-dataset  Netflix TV Shows and Movies (2022 Updated)       2MB  2022-11-27 20:41:41           2645         48  1.0
# whenamancodes/predict-diabities                                 Predict Diabetes                                 9KB  2022-11-09 12:18:49           8213        126  1.0
# kulturehire/understanding-career-aspirations-of-genz            Understanding Career Aspirations of GenZ         8KB  2022-12-21 13:44:32            281         23  0.9117647
# thedevastator/uncovering-wage-disparities-in-pennsylvania-s-hi  Higher Education Wages                         223KB  2022-12-04 15:42:36           1330         44  1.0
# laibaanwer/superstore-sales-dataset                             SuperStore Sales Dataset                         2MB  2022-12-07 08:53:32           1598         38  1.0
# catherinerasgaitis/mxmh-survey-results                          Music & Mental Health Survey Results            22KB  2022-11-21 10:03:12           3319         77  1.0

# %%
# download plant data
! kaggle datasets download -d abdallahalidev/plantvillage-dataset
# Out:
# Downloading plantvillage-dataset.zip to /content
# 100% 2.04G/2.04G [00:53<00:00, 42.4MB/s]
# 100% 2.04G/2.04G [00:53<00:00, 41.2MB/s]

# %%
# !unzip /content/plantvillage-dataset.zip
#make sure to add the '-' in 'plantvillage-dataset' ONLY once file unzips

# %%
# !pip install split_folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split_folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
import os

# if you get an 'already exists' error, comment out the makedirs lines

'''
os.makedirs('output')
os.makedirs('output/train')
os.makedirs('output/val')
os.makedirs('output/test')
'''

loc = "/content/plantvillage-dataset/color"

splitfolders.ratio(loc,output = "output",seed = 42,ratio = (0.80,.1,.1))
# Out:
# Copying files: 54305 files [00:10, 4976.87 files/s]

# %%
for root, dirs, files in os.walk('/content/output'):
  print(f'There are {len(dirs)} directories and {len(files)} images in "{root}"')
# Out:
# There are 3 directories and 0 images in "/content/output"
# There are 38 directories and 0 images in "/content/output/val"
# There are 0 directories and 535 images in "/content/output/val/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
# There are 0 directories and 63 images in "/content/output/val/Apple___Apple_scab"
# There are 0 directories and 62 images in "/content/output/val/Apple___Black_rot"
# There are 0 directories and 100 images in "/content/output/val/Tomato___Early_blight"
# There are 0 directories and 99 images in "/content/output/val/Pepper,_bell___Bacterial_spot"
# There are 0 directories and 150 images in "/content/output/val/Blueberry___healthy"
# There are 0 directories and 229 images in "/content/output/val/Peach___Bacterial_spot"
# There are 0 directories and 140 images in "/content/output/val/Tomato___Target_Spot"
# There are 0 directories and 159 images in "/content/output/val/Tomato___healthy"
# There are 0 directories and 36 images in "/content/output/val/Peach___healthy"
# There are 0 directories and 177 images in "/content/output/val/Tomato___Septoria_leaf_spot"
# There are 0 directories and 15 images in "/content/output/val/Potato___healthy"
# There are 0 directories and 138 images in "/content/output/val/Grape___Esca_(Black_Measles)"
# There are 0 directories and 105 images in "/content/output/val/Cherry_(including_sour)___Powdery_mildew"
# There are 0 directories and 100 images in "/content/output/val/Potato___Early_blight"
# There are 0 directories and 95 images in "/content/output/val/Tomato___Leaf_Mold"
# There are 0 directories and 212 images in "/content/output/val/Tomato___Bacterial_spot"
# There are 0 directories and 51 images in "/content/output/val/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot"
# There are 0 directories and 37 images in "/content/output/val/Tomato___Tomato_mosaic_virus"
# There are 0 directories and 45 images in "/content/output/val/Strawberry___healthy"
# There are 0 directories and 509 images in "/content/output/val/Soybean___healthy"
# There are 0 directories and 27 images in "/content/output/val/Apple___Cedar_apple_rust"
# There are 0 directories and 98 images in "/content/output/val/Corn_(maize)___Northern_Leaf_Blight"
# There are 0 directories and 183 images in "/content/output/val/Squash___Powdery_mildew"
# There are 0 directories and 116 images in "/content/output/val/Corn_(maize)___healthy"
# There are 0 directories and 167 images in "/content/output/val/Tomato___Spider_mites Two-spotted_spider_mite"
# There are 0 directories and 42 images in "/content/output/val/Grape___healthy"
# There are 0 directories and 550 images in "/content/output/val/Orange___Haunglongbing_(Citrus_greening)"
# There are 0 directories and 164 images in "/content/output/val/Apple___healthy"
# There are 0 directories and 190 images in "/content/output/val/Tomato___Late_blight"
# There are 0 directories and 85 images in "/content/output/val/Cherry_(including_sour)___healthy"
# There are 0 directories and 119 images in "/content/output/val/Corn_(maize)___Common_rust_"
# There are 0 directories and 100 images in "/content/output/val/Potato___Late_blight"
# There are 0 directories and 147 images in "/content/output/val/Pepper,_bell___healthy"
# There are 0 directories and 118 images in "/content/output/val/Grape___Black_rot"
# There are 0 directories and 110 images in "/content/output/val/Strawberry___Leaf_scorch"
# There are 0 directories and 107 images in "/content/output/val/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)"
# There are 0 directories and 37 images in "/content/output/val/Raspberry___healthy"
# There are 38 directories and 0 images in "/content/output/test"
# There are 0 directories and 537 images in "/content/output/test/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
# There are 0 directories and 63 images in "/content/output/test/Apple___Apple_scab"
# There are 0 directories and 63 images in "/content/output/test/Apple___Black_rot"
# There are 0 directories and 100 images in "/content/output/test/Tomato___Early_blight"
# There are 0 directories and 101 images in "/content/output/test/Pepper,_bell___Bacterial_spot"
# There are 0 directories and 151 images in "/content/output/test/Blueberry___healthy"
# There are 0 directories and 231 images in "/content/output/test/Peach___Bacterial_spot"
# There are 0 directories and 141 images in "/content/output/test/Tomato___Target_Spot"
# There are 0 directories and 160 images in "/content/output/test/Tomato___healthy"
# There are 0 directories and 36 images in "/content/output/test/Peach___healthy"
# There are 0 directories and 178 images in "/content/output/test/Tomato___Septoria_leaf_spot"
# There are 0 directories and 16 images in "/content/output/test/Potato___healthy"
# There are 0 directories and 139 images in "/content/output/test/Grape___Esca_(Black_Measles)"
# There are 0 directories and 106 images in "/content/output/test/Cherry_(including_sour)___Powdery_mildew"
# There are 0 directories and 100 images in "/content/output/test/Potato___Early_blight"
# There are 0 directories and 96 images in "/content/output/test/Tomato___Leaf_Mold"
# There are 0 directories and 214 images in "/content/output/test/Tomato___Bacterial_spot"
# There are 0 directories and 52 images in "/content/output/test/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot"
# There are 0 directories and 38 images in "/content/output/test/Tomato___Tomato_mosaic_virus"
# There are 0 directories and 47 images in "/content/output/test/Strawberry___healthy"
# There are 0 directories and 509 images in "/content/output/test/Soybean___healthy"
# There are 0 directories and 28 images in "/content/output/test/Apple___Cedar_apple_rust"
# There are 0 directories and 99 images in "/content/output/test/Corn_(maize)___Northern_Leaf_Blight"
# There are 0 directories and 184 images in "/content/output/test/Squash___Powdery_mildew"
# There are 0 directories and 117 images in "/content/output/test/Corn_(maize)___healthy"
# There are 0 directories and 169 images in "/content/output/test/Tomato___Spider_mites Two-spotted_spider_mite"
# There are 0 directories and 43 images in "/content/output/test/Grape___healthy"
# There are 0 directories and 552 images in "/content/output/test/Orange___Haunglongbing_(Citrus_greening)"
# There are 0 directories and 165 images in "/content/output/test/Apple___healthy"
# There are 0 directories and 192 images in "/content/output/test/Tomato___Late_blight"
# There are 0 directories and 86 images in "/content/output/test/Cherry_(including_sour)___healthy"
# There are 0 directories and 120 images in "/content/output/test/Corn_(maize)___Common_rust_"
# There are 0 directories and 100 images in "/content/output/test/Potato___Late_blight"
# There are 0 directories and 149 images in "/content/output/test/Pepper,_bell___healthy"
# There are 0 directories and 118 images in "/content/output/test/Grape___Black_rot"
# There are 0 directories and 112 images in "/content/output/test/Strawberry___Leaf_scorch"
# There are 0 directories and 109 images in "/content/output/test/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)"
# There are 0 directories and 38 images in "/content/output/test/Raspberry___healthy"
# There are 38 directories and 0 images in "/content/output/train"
# There are 0 directories and 4285 images in "/content/output/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
# There are 0 directories and 504 images in "/content/output/train/Apple___Apple_scab"
# There are 0 directories and 496 images in "/content/output/train/Apple___Black_rot"
# There are 0 directories and 800 images in "/content/output/train/Tomato___Early_blight"
# There are 0 directories and 797 images in "/content/output/train/Pepper,_bell___Bacterial_spot"
# There are 0 directories and 1201 images in "/content/output/train/Blueberry___healthy"
# There are 0 directories and 1837 images in "/content/output/train/Peach___Bacterial_spot"
# There are 0 directories and 1123 images in "/content/output/train/Tomato___Target_Spot"
# There are 0 directories and 1272 images in "/content/output/train/Tomato___healthy"
# There are 0 directories and 288 images in "/content/output/train/Peach___healthy"
# There are 0 directories and 1416 images in "/content/output/train/Tomato___Septoria_leaf_spot"
# There are 0 directories and 121 images in "/content/output/train/Potato___healthy"
# There are 0 directories and 1106 images in "/content/output/train/Grape___Esca_(Black_Measles)"
# There are 0 directories and 841 images in "/content/output/train/Cherry_(including_sour)___Powdery_mildew"
# There are 0 directories and 800 images in "/content/output/train/Potato___Early_blight"
# There are 0 directories and 761 images in "/content/output/train/Tomato___Leaf_Mold"
# There are 0 directories and 1701 images in "/content/output/train/Tomato___Bacterial_spot"
# There are 0 directories and 410 images in "/content/output/train/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot"
# There are 0 directories and 298 images in "/content/output/train/Tomato___Tomato_mosaic_virus"
# There are 0 directories and 364 images in "/content/output/train/Strawberry___healthy"
# There are 0 directories and 4072 images in "/content/output/train/Soybean___healthy"
# There are 0 directories and 220 images in "/content/output/train/Apple___Cedar_apple_rust"
# There are 0 directories and 788 images in "/content/output/train/Corn_(maize)___Northern_Leaf_Blight"
# There are 0 directories and 1468 images in "/content/output/train/Squash___Powdery_mildew"
# There are 0 directories and 929 images in "/content/output/train/Corn_(maize)___healthy"
# There are 0 directories and 1340 images in "/content/output/train/Tomato___Spider_mites Two-spotted_spider_mite"
# There are 0 directories and 338 images in "/content/output/train/Grape___healthy"
# There are 0 directories and 4405 images in "/content/output/train/Orange___Haunglongbing_(Citrus_greening)"
# There are 0 directories and 1316 images in "/content/output/train/Apple___healthy"
# There are 0 directories and 1527 images in "/content/output/train/Tomato___Late_blight"
# There are 0 directories and 683 images in "/content/output/train/Cherry_(including_sour)___healthy"
# There are 0 directories and 953 images in "/content/output/train/Corn_(maize)___Common_rust_"
# There are 0 directories and 800 images in "/content/output/train/Potato___Late_blight"
# There are 0 directories and 1182 images in "/content/output/train/Pepper,_bell___healthy"
# There are 0 directories and 944 images in "/content/output/train/Grape___Black_rot"
# There are 0 directories and 887 images in "/content/output/train/Strawberry___Leaf_scorch"
# There are 0 directories and 860 images in "/content/output/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)"
# There are 0 directories and 296 images in "/content/output/train/Raspberry___healthy"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping
import matplotlib
import random

def plot_random_image(target_dir,target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder),1)
    img = mping.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off");
    return img

# %%
# plot some random samples from the training dataset

fig = plt.figure(figsize = (10,7))
fig.add_subplot(2,2,1)
img_1 = plot_random_image(target_dir = "/content/output/train",target_class = "/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot")
fig.add_subplot(2,2,2)
img_2 = plot_random_image(target_dir = "/content/output/train",target_class = "/Corn_(maize)___healthy")
fig.add_subplot(2,2,3)
img_3 = plot_random_image(target_dir = "/content/output/train",target_class = "/Corn_(maize)___Northern_Leaf_Blight")
fig.add_subplot(2,2,4)
img_4 = plot_random_image(target_dir = "/content/output/train",target_class = "/Corn_(maize)___Common_rust_")

# %%
def find_file_count(path):
  cpt = sum([len(files) for r, d, files in os.walk(f"{path}")])
  return cpt

train_length = find_file_count('/content/output/train')
test_length = find_file_count('/content/output/test')
val_length = find_file_count('/content/output/val')
print(f'Training images: {train_length}, Testing images: {test_length}, Validation images: {val_length}')
# Out:
# Training images: 43429, Testing images: 5459, Validation images: 5417

# %%
import glob
import shutil

# if 'already exists' message, comment out makedirs line below

train_img_fol = glob.glob('/content/output/train')
test_img_fol = glob.glob('/content/output/test')
val_img_fol =  glob.glob('/content/output/val')

def move_directory(initial, end, corn_list):
  for i in corn_list:
    shutil.move(initial + '/' + i, end + '/' + i)


corn_list = ['Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___healthy', 
            'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___Common_rust_']

move_directory('/content/output/train', '/content/output/train/corn', corn_list)
move_directory('/content/output/test', '/content/output/test/corn', corn_list)
move_directory('/content/output/val', '/content/output/val/corn', corn_list)

# %%
tr_gls = glob.glob('/content/output/train/corn/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot/*')
tr_cr = glob.glob('/content/output/train/corn/Corn_(maize)___Common_rust_/*')
tr_nlb = glob.glob('/content/output/train/corn/Corn_(maize)___Northern_Leaf_Blight/*')
tr_hlt = glob.glob('/content/output/train/corn/Corn_(maize)___healthy/*')

val_gls = glob.glob('/content/output/val/corn/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot/*')
val_cr = glob.glob('/content/output/val/corn/Corn_(maize)___Common_rust_/*')
val_nlb = glob.glob('/content/output/val/corn/Corn_(maize)___Northern_Leaf_Blight/*')
val_hlt = glob.glob('/content/output/val/corn/Corn_(maize)___healthy/*')

te_gls = glob.glob('/content/output/test/corn/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot/*')
te_cr = glob.glob('/content/output/test/corn/Corn_(maize)___Common_rust_/*')
te_nlb = glob.glob('/content/output/test/corn/Corn_(maize)___Northern_Leaf_Blight/*')
te_hlt = glob.glob('/content/output/test/corn/Corn_(maize)___healthy/*')

train_files = []
val_files = []
test_files = []

def appendimages(files, gls, cr, nlb, hlt):
  for i in gls:
    files.append(i)
  for i in cr:
    files.append(i)
  for i in nlb:
    files.append(i)
  for i in hlt:
    files.append(i)

appendimages(train_files, tr_gls, tr_cr, tr_nlb, tr_hlt)
appendimages(test_files, te_gls, te_cr, te_nlb, te_hlt)
appendimages(val_files, val_gls, val_cr, val_nlb, val_hlt)

total_files = []
for i in train_files:
  total_files.append(i)
for i in val_files:
  total_files.append(i)
for i in test_files:
  total_files.append(i)

print(len(train_files), len(val_files), len(test_files))
print(len(total_files))
# Out:
# 3080 384 388
# 3852

# %%
total_gls = len(te_gls) + len(val_gls) + len(tr_gls)
total_cr = len(te_cr) + len(val_cr) + len(tr_cr)
total_nlb = len(te_nlb) + len(val_nlb) + len(tr_nlb)
total_hlt = len(te_hlt) + len(val_hlt) + len(tr_hlt)
total_images = total_gls + total_cr + total_nlb + total_hlt

print(total_gls, total_cr, total_nlb, total_hlt)
print(total_images)
fig = plt.figure(figsize=(8.5, 5))

plt.bar(['Gray Leaf Spot', 'Common Rust', 'Northern Leaf Blight', 'Healthy'], 
        [total_gls, total_cr, total_nlb, total_hlt], color=['gray', 'orange', 'blue', 'green'])
# Out:
# 513 1192 985 1162
# 3852
# <BarContainer object of 4 artists>

# %%
# find file sizes
import cv2
import torch
import torchvision.transforms as transforms

train_file_shapes = 0

for i in train_files:
  i = cv2.imread(i) # returns np ndarray
  shp = i.shape[0]
  train_file_shapes += shp

mean_train_file_size = train_file_shapes/len(train_files)
print(mean_train_file_size)

val_file_shapes = 0

for i in val_files:
  i = cv2.imread(i) # returns np ndarray
  shp = i.shape[0]
  val_file_shapes += shp

mean_val_file_size = val_file_shapes/len(val_files)
print(mean_val_file_size)

test_file_shapes = 0

for i in test_files:
  i = cv2.imread(i) # returns np ndarray
  shp = i.shape[0]
  test_file_shapes += shp

mean_test_file_size = test_file_shapes/len(test_files)
print(mean_test_file_size)
# Out:
# 256.0
# 256.0
# 256.0

# %%
from re import M
def findMeans(files, mean_file_size):
  num_pixels = len(files) * mean_file_size * mean_file_size

  sum = 0
  for i in files:
    i = cv2.imread(i)
    i = cv2.resize(i, (int(mean_file_size), int(mean_file_size)))
    transform = transforms.Compose([transforms.ToTensor()])
    i_tensor = transform(i)
    sum += i_tensor[0].sum() #sum across one channel, so grab 0th index
    mean = sum / num_pixels

  sum_squared_error = 0 #std deviation
  for i in files:
    i = cv2.imread(i)
    i = cv2.resize(i, (int(mean_file_size), int(mean_file_size)))
    transform = transforms.Compose([transforms.ToTensor()])
    i_tensor = transform(i)
    sum_squared_error += ((i_tensor[0] - mean)**2).sum()
    std_dev = (sum_squared_error / num_pixels) ** 0.5

  print('Mean: ', mean)
  print('Standard Deviation: ', std_dev)
  return mean, std_dev

train_mean, train_std_dev = findMeans(train_files, mean_train_file_size)
val_mean, val_std_dev = findMeans(val_files, mean_val_file_size)
test_mean, test_std_dev = findMeans(test_files, mean_test_file_size)
# Out:
# Mean:  tensor(0.3792)
# Standard Deviation:  tensor(0.2115)
# Mean:  tensor(0.3751)
# Standard Deviation:  tensor(0.2157)
# Mean:  tensor(0.3766)
# Standard Deviation:  tensor(0.2106)

# %%
import torch
import torchvision
import torchvision.transforms as transforms

tr_image_data = []
val_image_data = []
te_image_data = []
tr_label_data = []
val_label_data = []
te_label_data = []


def loading_dataset(lst, data_list, label_list, yn_transforms, mean, std_dev):
  count = 0
  for i in lst: 
    if 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot' in i:
      label_list.append(int(0))
    elif 'Corn_(maize)___Common_rust_' in i:
      label_list.append(int(1))
    elif 'Corn_(maize)___Northern_Leaf_Blight' in i:
      label_list.append(int(2))
    elif 'Corn_(maize)___healthy' in i:
      label_list.append(int(3))
      
    img = cv2.imread(str(i))
    img = cv2.resize(img, (128, 128))

    if yn_transforms == True:
      transform = transforms.Compose([transforms.ToTensor(),
                                      transforms.RandomHorizontalFlip(p=0.5),
                                      transforms.RandomVerticalFlip(p=0.5),
                                      transforms.Normalize(mean, std_dev)])
        
      img = transform(img)

      if count % 5 == 0:
        additional_transform = transforms.Compose([transforms.RandomRotation(degrees=(90))])
        img = additional_transform(img)
        
      data_list.append(img)
      
    elif yn_transforms == False:
      transform = transforms.Compose([transforms.ToTensor(),
                                        transforms.Normalize(mean, std_dev)])
        
      img = transform(img)
      data_list.append(img)

    count += 1

# %%
loading_dataset(train_files, tr_image_data, tr_label_data, True, train_mean, train_std_dev)
print(tr_image_data[0].shape)
# output has 3 channels, and is a 128 pixel by 128 pixel image
# Out:
# torch.Size([3, 128, 128])

# %%
loading_dataset(val_files, val_image_data, val_label_data, True, val_mean, val_std_dev)
print(val_image_data[0].shape)
# Out:
# torch.Size([3, 128, 128])

# %%
loading_dataset(test_files, te_image_data, te_label_data, False, test_mean, test_std_dev)
print(te_image_data[0].shape)
# Out:
# torch.Size([3, 128, 128])

# %%
# check to see that labels and images align
print(len(tr_image_data), len(tr_label_data))
print(len(val_image_data), len(val_label_data))
print(len(te_image_data), len(te_label_data))
# Out:
# 3080 3080
# 384 384
# 388 388

# %%
# using batch of 32, so will reduce images to have data % 32 = 0

model_train_images = tr_image_data[:3072]
model_train_labels = tr_label_data[:3072]

model_val_images = val_image_data[:384]
model_val_labels = val_label_data[:384]

model_test_images = te_image_data[:384]
model_test_labels = te_label_data[:384]

print(len(model_train_images), len(model_train_labels))
print(len(model_val_images), len(model_val_labels))
print(len(model_test_images), len(model_test_labels))
# Out:
# 3072 3072
# 384 384
# 384 384

# %%
import random

training_data = list(zip(model_train_images, model_train_labels))
validation_data = list(zip(model_val_images, model_val_labels))
testing_data = list(zip(model_test_images, model_test_labels))

random.shuffle(training_data)
random.shuffle(validation_data)
random.shuffle(testing_data)

print(len(training_data))
print(len(validation_data))
print(len(testing_data))
# Out:
# 3072
# 384
# 384

# %%
trainloader = torch.utils.data.DataLoader(training_data, shuffle=True, batch_size=32)
validationloader = torch.utils.data.DataLoader(validation_data, shuffle=True, batch_size=32)
testloader = torch.utils.data.DataLoader(testing_data, shuffle=True, batch_size=32)

# %%
print(len(trainloader))
print(len(validationloader))
print(len(testloader))
# Out:
# 96
# 12
# 12

# %%
categories = ['Gray Leaf Spot', 'Common Rust', 'Northern Leaf Blight', 'Healthy']

# %%
print("Training Images:")
train_images_batch, train_label_batch = next(iter(trainloader))
print(categories[(train_label_batch[0])], "\n")
print(train_images_batch.shape)
print(len(train_label_batch))
train_images_batch = train_images_batch.permute(0,2,3,1)
plt.imshow(train_images_batch[0])
plt.show()

print('\n'+"Validation Images:")
val_images_batch, val_label_batch = next(iter(validationloader))
print(categories[(val_label_batch[0])], "\n")
print(val_images_batch.shape)
print(len(val_label_batch))
val_images_batch = val_images_batch.permute(0,2,3,1)
plt.imshow(val_images_batch[0])
plt.show()

print('\n'+"Testing Images:")
test_images_batch, test_label_batch = next(iter(testloader))
print(categories[(test_label_batch[0])], "\n")
print(test_images_batch.shape)
print(len(test_label_batch))
test_images_batch = test_images_batch.permute(0,2,3,1)
plt.imshow(test_images_batch[0])
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Training Images:
# Northern Leaf Blight
#
# torch.Size([32, 3, 128, 128])
# 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Validation Images:
# Common Rust
#
# torch.Size([32, 3, 128, 128])
# 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Testing Images:
# Healthy
#
# torch.Size([32, 3, 128, 128])
# 32

# %%
from torch.nn.modules.linear import Linear
from torch.nn.modules.batchnorm import BatchNorm2d
from torch import nn

model = nn.Sequential(
    # 128 x 128 x 3
    nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(16),
    # 128 x 128 x 16
    nn.MaxPool2d(2,2),
    # 64 x 64 x 16
    nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(32),
    # 64 x 64 x 32
    nn.MaxPool2d(2,2),
    # 32, 32, 32
    nn.Flatten(),
    # 1 x 32768
    nn.Linear(32*32*32, 512),
    nn.ReLU(),
    nn.Dropout(p=0.7),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(p=0.6),
    nn.Linear(256,4),
    nn.Softmax(dim=1)
)

# %%
print(model)
# Out:
# Sequential(
#   (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): ReLU()
#   (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (8): Flatten(start_dim=1, end_dim=-1)
#   (9): Linear(in_features=32768, out_features=512, bias=True)
#   (10): ReLU()
#   (11): Dropout(p=0.7, inplace=False)
#   (12): Linear(in_features=512, out_features=256, bias=True)
#   (13): ReLU()
#   (14): Dropout(p=0.6, inplace=False)
#   (15): Linear(in_features=256, out_features=4, bias=True)
#   (16): Softmax(dim=1)
# )

# %%
input = torch.rand(1,3, 128, 128)
print(input.shape)

output = model(input)
print(output.shape)
# Out:
# torch.Size([1, 3, 128, 128])
# torch.Size([1, 4])

# %%
from torch import optim
import datetime 

optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# %%
training_losses = []
validation_losses = []

epochs = 20 

for epoch in range(epochs):
  start_epoch = datetime.datetime.now()
  training_loss = 0
  validation_loss = 0
  model.train()
  for images, labels in trainloader:
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    training_loss += loss.item()

  model.eval()

  for images, labels in validationloader:
    images, labels = next(iter(validationloader))
    outputs = model(images)
    loss = criterion(outputs, labels)

    validation_loss += loss.item()

  mean_training_loss = training_loss / len(trainloader)
  mean_validation_loss = validation_loss / len(validationloader)

  training_losses.append(mean_training_loss)
  validation_losses.append(mean_validation_loss)

  print('Epoch: {} | Training Loss:{:.4f} | Validation Loss:{:.4f}'.format(epoch+1, mean_training_loss, mean_validation_loss))

  if mean_validation_loss <= min(validation_losses):
    torch.save(model.state_dict(), 'diseaseclassificationmodel.pth')

  end_epoch = datetime.datetime.now()
  print('Epoch time: ', str(end_epoch-start_epoch), '\n')
# Out:
# Epoch: 1 | Training Loss:0.9663 | Validation Loss:0.9018
# Epoch time:  0:00:46.671113
#
# Epoch: 2 | Training Loss:0.8859 | Validation Loss:0.8906
# Epoch time:  0:00:46.942573
#
# Epoch: 3 | Training Loss:0.8797 | Validation Loss:0.8584
# Epoch time:  0:00:46.253615
#
# Epoch: 4 | Training Loss:0.8625 | Validation Loss:0.8407
# Epoch time:  0:00:45.955935
#
# Epoch: 5 | Training Loss:0.8582 | Validation Loss:0.8456
# Epoch time:  0:00:45.568588
#
# Epoch: 6 | Training Loss:0.8561 | Validation Loss:0.8687
# Epoch time:  0:00:45.614288
#
# Epoch: 7 | Training Loss:0.8469 | Validation Loss:0.8397
# Epoch time:  0:00:45.653749
#
# Epoch: 8 | Training Loss:0.8401 | Validation Loss:0.8561
# Epoch time:  0:00:45.591371
#
# Epoch: 9 | Training Loss:0.8418 | Validation Loss:0.8426
# Epoch time:  0:00:46.868547
#
# Epoch: 10 | Training Loss:0.8315 | Validation Loss:0.8586
# Epoch time:  0:00:46.125456
#
# Epoch: 11 | Training Loss:0.8275 | Validation Loss:0.8037
# Epoch time:  0:00:46.213330
#
# Epoch: 12 | Training Loss:0.8214 | Validation Loss:0.8404
# Epoch time:  0:00:46.035562
#
# Epoch: 13 | Training Loss:0.8148 | Validation Loss:0.8408
# Epoch time:  0:00:46.388999
#
# Epoch: 14 | Training Loss:0.8092 | Validation Loss:0.8482
# Epoch time:  0:00:46.265637
#
# Epoch: 15 | Training Loss:0.8057 | Validation Loss:0.8468
# Epoch time:  0:00:47.190527
#
# Epoch: 16 | Training Loss:0.7988 | Validation Loss:0.8270
# Epoch time:  0:00:46.209989
#
# Epoch: 17 | Training Loss:0.8019 | Validation Loss:0.8480
# Epoch time:  0:00:46.282995
#
# Epoch: 18 | Training Loss:0.7956 | Validation Loss:0.8652
# Epoch time:  0:00:46.761412
#
# Epoch: 19 | Training Loss:0.7899 | Validation Loss:0.8217
# Epoch time:  0:00:46.396084
#
# Epoch: 20 | Training Loss:0.7875 | Validation Loss:0.8199
# Epoch time:  0:00:46.757704

# %%
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')

# %%
import numpy as np

test_correct = [0,0,0,0]
test_total = [0,0,0,0] 
total_testing_loss = 0

for images, labels in testloader:
  torch.no_grad()
  outputs = model(images)
  testing_loss = criterion(outputs, labels)

  total_testing_loss += testing_loss.item()

  probabilities = torch.exp(outputs)
  top_probs, top_cats = probabilities.topk(1, dim=1)

  for i in range(32):
    label = labels.data[i]
    pred = top_cats[i]
    if label == pred:
      test_correct[label] +=1
    test_total[label] += 1

print('Testing Loss:', int(total_testing_loss)/len(testloader), '\n')

gls_acc = (test_correct[0]/test_total[0]) * 100
cr_acc = (test_correct[1]/test_total[1]) * 100
nlb_acc = (test_correct[2]/test_total[2]) * 100
hlt_acc = (test_correct[3]/test_total[3]) * 100

total_accuracy = (gls_acc + cr_acc + nlb_acc + hlt_acc) / 4

print("Total Testing Accuracy: {:.2f}".format(total_accuracy))
print("Gray Leaf Spot Accuracy: {:.2f} | ({}/{})".format(gls_acc, test_correct[0], test_total[0]))
print("Common Rust Accuracy: {:.2f} | ({}/{})".format(cr_acc, test_correct[1], test_total[1]))
print("Northern Leaf Blight Accuracy: {:.2f} | ({}/{})".format(nlb_acc, test_correct[2], test_total[2]))
print("Healthy Accuracy: {:.2f} | ({}/{})".format(hlt_acc, test_correct[3], test_total[3]))
# Out:
# Testing Loss: 0.75
#
# Total Testing Accuracy: 91.45
# Gray Leaf Spot Accuracy: 76.92 | (40/52)
# Common Rust Accuracy: 100.00 | (120/120)
# Northern Leaf Blight Accuracy: 88.89 | (88/99)
# Healthy Accuracy: 100.00 | (113/113)
